# %%
.import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/netflix(1).csv')
df.head()
# Out:
#                title            genre language  imdb_score    premiere  \
# 0   Notes for My Son            Drama  Spanish         6.3  11/24/2020
# 1   To Each, Her Own  Romantic comedy   French         5.3   6/24/2018
# 2      The Lovebirds  Romantic comedy  English         6.1   5/22/2020
# 3     The Perfection  Horror-thriller  English         6.1   5/24/2019
# 4  Happy Anniversary  Romantic comedy  English         5.8   3/30/2018
#
#    runtime  year
# 0       83  2020
# 1       95  2018
# 2       87  2020
# 3       90  2019
# 4       78  2018

# %%
df.describe()
# Out:
#        imdb_score     runtime         year
# count  583.000000  583.000000   583.000000
# mean     6.275129   93.490566  2018.934820
# std      0.976678   27.706665     1.474598
# min      2.500000    4.000000  2014.000000
# 25%      5.700000   86.000000  2018.000000
# 50%      6.400000   97.000000  2019.000000
# 75%      7.000000  107.500000  2020.000000
# max      9.000000  209.000000  2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       583 non-null    object
#  1   genre       583 non-null    object
#  2   language    583 non-null    object
#  3   imdb_score  583 non-null    float64
#  4   premiere    583 non-null    object
#  5   runtime     583 non-null    int64
#  6   year        583 non-null    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 32.0+ KB

# %%
df_redefined = df.drop(columns=['year'])
df_redefined.sample(5)
# Out:
#                                        title            genre language  \
# 337                           Back to School           Comedy   French
# 552                             American Son            Drama  English
# 100                               Sextuplets           Comedy  English
# 166  Chadwick Boseman: Portrait of an Artist      Documentary  English
# 59                       The Princess Switch  Romantic comedy  English
#
#      imdb_score    premiere  runtime
# 337         5.3   8/30/2019       83
# 552         5.8  11-01-2019       90
# 100         4.4   8/16/2019       99
# 166         6.5   4/17/2021       21
# 59          6.0  11/16/2018      101

# %%
df_redefined.isnull().sum()
# Out:
# title         0
# genre         0
# language      0
# imdb_score    0
# premiere      0
# runtime       0
# dtype: int64

# %%
max_imbdScore_col = df_redefined['imdb_score'].idxmax()
max_imbdScore = df_redefined.iloc[max_imbdScore_col]
max_imbdScore
# Out:
# title         David Attenborough: A Life on Our Planet
# genre                                      Documentary
# language                                       English
# imdb_score                                         9.0
# premiere                                    10-04-2020
# runtime                                             83
# Name: 285, dtype: object

# %%
common_genre = df_redefined['genre'].value_counts().idxmax()
common_genre
# Out:
# 'Documentary'

# %%
df_redefined.genre.value_counts()['Documentary']
# Out:
# 159

# %%
mean_imdbScore = df.groupby('genre')['imdb_score'].mean()
mean_imdbScore
# Out:
# genre
# Action              5.414286
# Action comedy       5.420000
# Action thriller     6.400000
# Action-adventure    7.300000
# Action-thriller     6.133333
#                       ...
# War                 6.750000
# War drama           7.100000
# War-Comedy          6.000000
# Western             6.066667
# Zombie/Heist        5.900000
# Name: imdb_score, Length: 114, dtype: float64

# %%
genre_count_per_year = df.groupby(['year','genre']).size()
genre_count_per_year
# Out:
# year  genre
# 2014  Documentary                 1
# 2015  Comedy / Musical            1
#       Documentary                 6
#       War drama                   1
#       Western                     1
#                                  ..
# 2021  Science fiction             1
#       Science fiction thriller    1
#       Superhero-Comedy            1
#       Thriller                    4
#       Zombie/Heist                1
# Length: 199, dtype: int64

# %%
runtime_avgIMDB = df.groupby('runtime')['imdb_score'].mean()
runtime_avgIMDB
# Out:
# runtime
# 4      4.70
# 7      6.90
# 9      6.50
# 10     5.20
# 11     7.20
#        ...
# 149    6.20
# 151    6.25
# 153    8.50
# 155    6.50
# 209    7.80
# Name: imdb_score, Length: 124, dtype: float64

# %%
genre_count_per_language = df.groupby(['language','genre']).size()
genre_count_per_language
# Out:
# language      genre
# Bengali       Documentary        1
# Dutch         Crime drama        1
#               Fantasy            1
#               Romantic comedy    1
# English       Action             4
#                                 ..
# Thai          Horror             1
# Thia/English  Documentary        1
# Turkish       Comedy             2
#               Drama              2
#               Romance            1
# Length: 203, dtype: int64

# %%
activeLanguage = df_redefined['language'].value_counts().idxmax()
activeLanguage
# Out:
# 'English'

# %% [markdown]
# Dataset:
#   In this project we have analyzed the Netflix dataset containing Movie name, Genre, Language, Rating (IMDB Score), Date released and Runtime.

# %% [markdown]
# CONCLUSION:
#   From this analysis we came to know that English movies are more commonly released in Netflix with a film named "A Life On Our Planet" being the highly rated film. We have also analysed movie ratins based on various features.
